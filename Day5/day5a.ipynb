# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# Running cells with 'kagglexgoogle (Python 3.12.12)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Sony/Desktop/KaggleXGoogle/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
import json
import requests
import subprocess
import time
import uuid

from google.adk.agents import LlmAgent
from google.adk.agents.remote_a2a_agent import (
    RemoteA2aAgent,
    AGENT_CARD_WELL_KNOWN_PATH,
)

from google.adk.a2a.utils.agent_to_a2a import to_a2a
from google.adk.models.google_llm import Gemini
from google.adk.runners import Runner
from google.adk.sessions import InMemorySessionService
from google.genai import types

# Hide additional warnings in the notebook
import warnings

warnings.filterwarnings("ignore")

print("✅ ADK components imported successfully.")
# Out:
# c:\Users\Sony\Desktop\KaggleXGoogle\.venv\lib\site-packages\google\api_core\_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.0) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 8
#       5 import uuid
#       7 from google.adk.agents import LlmAgent
# ----> 8 from google.adk.agents.remote_a2a_agent import (
#       9     RemoteA2aAgent,
#      10     AGENT_CARD_WELL_KNOWN_PATH,
#      11 )
#      13 from google.adk.a2a.utils.agent_to_a2a import to_a2a
#      14 from google.adk.models.google_llm import Gemini
#
# File c:\Users\Sony\Desktop\KaggleXGoogle\.venv\lib\site-packages\google\adk\agents\remote_a2a_agent.py:51
#      47     raise ImportError(
#      48         "A2A requires Python 3.10 or above. Please upgrade your Python version."
#      49     ) from e
#      50   else:
# ---> 51     raise e
#      53 try:
#      54   from a2a.utils.constants import AGENT_CARD_WELL_KNOWN_PATH
#
# File c:\Users\Sony\Desktop\KaggleXGoogle\.venv\lib\site-packages\google\adk\agents\remote_a2a_agent.py:29
#      26 import uuid
#      28 try:
# ---> 29   from a2a.client import Client as A2AClient
#      30   from a2a.client import ClientEvent as A2AClientEvent
#      31   from a2a.client.card_resolver import A2ACardResolver
#
# ModuleNotFoundError: No module named 'a2a'

# %%
retry_config = types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],  # Retry on these HTTP errors
)
